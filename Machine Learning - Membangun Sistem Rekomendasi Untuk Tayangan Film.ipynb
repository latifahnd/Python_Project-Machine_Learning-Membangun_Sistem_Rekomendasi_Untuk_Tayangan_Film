# %% [markdown]
# # Machine Learning: Membangun Sistem Rekomendasi Untuk Tayangan Film
# #### by: Nadia Fitriana Latifah

# %% [markdown]
# ## Overview
# #### Pada pembuatan sistem rekomendasi ini menggunakan database film dari IMDB dan menggunakan dua jenis sistem rekomendasi:
# #### 1. Sistem rekomendasi sederhana.
# #### 2. Sistem rekomendasi berdasarkan konten dan fitur.
# #### Pada sistem rekomendasi sederhana, hanya mengurutkan film berdasarkan dari perhitungan 5 film terbaik.
# #### Dalam pembuatan sistem rekomendasi untuk tayangan film ini mengurutkan film berdasarkan dari rating tertinggi, vote terbanyak, dan membuat metric baru dari metric yang telah ada, kemudian melakukan sorting untuk metric baru dari urutan tertinggi sampai terendah.
# #### Rekomendasi yang digunakan adalah "Simple Recommender Engine using Weighted Average" yang merupakan rekomendasi umum untuk semua user berdasarkan popularitas film ataupun genre film.
# #### Formula dari IMDB dengan Weighted Rating adalah sebagai berikut:

# %% [markdown]
# $$ Weighted Rating (WR) = (v/(v+m).R) + (m/(v+m).C) $$

# %% [markdown]
# #### dengan:
# #### v = jumlah votes pada film,
# #### m = jumlah minimum votes yang diperlukan agar dapat masuk dalam chart kategori,
# #### R = rata-ratang rating film,
# #### C = rata-rata jumlah votes dari seluruh genre film.

# %%
import numpy as np
import pandas as pd

# %%
df_film=pd.read_csv('title_basics.csv')
df_rating=pd.read_csv('title_ratings.csv', sep='\t')

# %%
df_film
# Out:
#          tconst  titleType                                       primaryTitle  \
# 0     tt0221078      short                          Circle Dance, Ute Indians
# 1     tt8862466  tvEpisode   ¡El #TeamOsos va con todo al "Reality del amor"!
# 2     tt7157720  tvEpisode                                      Episode #3.41
# 3     tt2974998  tvEpisode                          Episode dated 16 May 1987
# 4     tt2903620  tvEpisode                   Frances Bavier: Aunt Bee Retires
# ...         ...        ...                                                ...
# 9020  tt3984412  tvEpisode  I'm Not Going to Come Last, I'm Just Going to ...
# 9021  tt8740950  tvEpisode  Weight Loss Resolution Restart - Ins & Outs of...
# 9022  tt9822816  tvEpisode  Zwischen Vertuschung und Aufklärung - Missbrau...
# 9023  tt9900062  tvEpisode  The Direction of Yuu's Love: Hings Aren't Goin...
# 9024  tt9909210  tvEpisode  Politik und/oder Moral - Wie weit geht das Ver...
#
#                                          originalTitle  isAdult startYear  \
# 0                            Circle Dance, Ute Indians        0      1898
# 1     ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                        Episode #3.41        0      2016
# 3                            Episode dated 16 May 1987        0      1987
# 4                     Frances Bavier: Aunt Bee Retires        0      1973
# ...                                                ...      ...       ...
# 9020                                                 0     2014        \N
# 9021                                                 0     2015        \N
# 9022                                                 0     2019        \N
# 9023                                                 0     1994        \N
# 9024                                                 0     2005        \N
#
#      endYear          runtimeMinutes             genres
# 0         \N                      \N  Documentary,Short
# 1         \N                      \N       Comedy,Drama
# 2         \N                      29   Comedy,Game-Show
# 3         \N                      \N               News
# 4         \N                      \N        Documentary
# ...      ...                     ...                ...
# 9020      \N              Reality-TV                NaN
# 9021      \N              Reality-TV                NaN
# 9022      \N                      \N                NaN
# 9023      \N  Animation,Comedy,Drama                NaN
# 9024      \N                      \N                NaN
#
# [9025 rows x 9 columns]

# %%
df_film.shape
# Out:
# (9025, 9)

# %%
df_film.head()
# Out:
#       tconst  titleType                                      primaryTitle  \
# 0  tt0221078      short                         Circle Dance, Ute Indians
# 1  tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2  tt7157720  tvEpisode                                     Episode #3.41
# 3  tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4  tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
#
#                                       originalTitle  isAdult startYear  \
# 0                         Circle Dance, Ute Indians        0      1898
# 1  ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                     Episode #3.41        0      2016
# 3                         Episode dated 16 May 1987        0      1987
# 4                  Frances Bavier: Aunt Bee Retires        0      1973
#
#   endYear runtimeMinutes             genres
# 0      \N             \N  Documentary,Short
# 1      \N             \N       Comedy,Drama
# 2      \N             29   Comedy,Game-Show
# 3      \N             \N               News
# 4      \N             \N        Documentary

# %%
df_film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9025 entries, 0 to 9024
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          9025 non-null   object
#  1   titleType       9025 non-null   object
#  2   primaryTitle    9011 non-null   object
#  3   originalTitle   9011 non-null   object
#  4   isAdult         9025 non-null   int64
#  5   startYear       9025 non-null   object
#  6   endYear         9025 non-null   object
#  7   runtimeMinutes  9025 non-null   object
#  8   genres          9014 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 634.7+ KB

# %% [markdown]
# ## Cleaning Table Movie
# #### Dalam hal ini dilakukan pengecekan terhadap data yang memiliki nilai NULL. Pengecekan dilakukan pada tabel movie(df_film) yang memiliki data bernilai NULL yang harus dihapus.

# %%
df_film.isnull().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      14
# originalTitle     14
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            11
# dtype: int64

# %% [markdown]
# #### Pengecekan data bernilai NULL juga dilakukan pada kolom 'primaryTitle' dan 'originalTitle' yang terdapat banyak data bernilai NULL.

# %%
df_film.loc[(df_film['primaryTitle'].isnull()) | (df_film['originalTitle'].isnull())]
# Out:
#           tconst  titleType primaryTitle originalTitle  isAdult startYear  \
# 9000  tt10790040  tvEpisode          NaN           NaN        0      2019
# 9001  tt10891902  tvEpisode          NaN           NaN        0      2020
# 9002  tt11737860  tvEpisode          NaN           NaN        0      2020
# 9003  tt11737862  tvEpisode          NaN           NaN        0      2020
# 9004  tt11737866  tvEpisode          NaN           NaN        0      2020
# 9005  tt11737872  tvEpisode          NaN           NaN        0      2020
# 9006  tt11737874  tvEpisode          NaN           NaN        0      2020
# 9007   tt1971246  tvEpisode          NaN           NaN        0      2011
# 9008   tt2067043  tvEpisode          NaN           NaN        0      1965
# 9009   tt4404732  tvEpisode          NaN           NaN        0      2015
# 9010   tt5773048  tvEpisode          NaN           NaN        0      2015
# 9011   tt8473688  tvEpisode          NaN           NaN        0      1987
# 9012   tt8541336  tvEpisode          NaN           NaN        0      2018
# 9013   tt9824302  tvEpisode          NaN           NaN        0      2016
#
#      endYear runtimeMinutes                genres
# 9000      \N             \N                    \N
# 9001      \N             \N                 Crime
# 9002      \N             \N  Comedy,Drama,Romance
# 9003      \N             \N  Comedy,Drama,Romance
# 9004      \N             \N  Comedy,Drama,Romance
# 9005      \N             \N                    \N
# 9006      \N             \N  Comedy,Drama,Romance
# 9007      \N             \N             Biography
# 9008      \N             \N                 Music
# 9009      \N             \N                Comedy
# 9010      \N             \N             Talk-Show
# 9011      \N             \N                 Drama
# 9012      \N             \N    Reality-TV,Romance
# 9013      \N             \N           Documentary

# %% [markdown]
# #### Menghapus data dengan nilai NULL.
# #### Dalam tabel diatas diketahui bahwa semua data tidak terdapat judul film sehingga data-data tersebut harus dihapus.

# %%
df_film=df_film.loc[(df_film['primaryTitle'].notnull()) & (df_film['originalTitle'].notnull())]

# %%
df_film
# Out:
#          tconst  titleType                                       primaryTitle  \
# 0     tt0221078      short                          Circle Dance, Ute Indians
# 1     tt8862466  tvEpisode   ¡El #TeamOsos va con todo al "Reality del amor"!
# 2     tt7157720  tvEpisode                                      Episode #3.41
# 3     tt2974998  tvEpisode                          Episode dated 16 May 1987
# 4     tt2903620  tvEpisode                   Frances Bavier: Aunt Bee Retires
# ...         ...        ...                                                ...
# 9020  tt3984412  tvEpisode  I'm Not Going to Come Last, I'm Just Going to ...
# 9021  tt8740950  tvEpisode  Weight Loss Resolution Restart - Ins & Outs of...
# 9022  tt9822816  tvEpisode  Zwischen Vertuschung und Aufklärung - Missbrau...
# 9023  tt9900062  tvEpisode  The Direction of Yuu's Love: Hings Aren't Goin...
# 9024  tt9909210  tvEpisode  Politik und/oder Moral - Wie weit geht das Ver...
#
#                                          originalTitle  isAdult startYear  \
# 0                            Circle Dance, Ute Indians        0      1898
# 1     ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                        Episode #3.41        0      2016
# 3                            Episode dated 16 May 1987        0      1987
# 4                     Frances Bavier: Aunt Bee Retires        0      1973
# ...                                                ...      ...       ...
# 9020                                                 0     2014        \N
# 9021                                                 0     2015        \N
# 9022                                                 0     2019        \N
# 9023                                                 0     1994        \N
# 9024                                                 0     2005        \N
#
#      endYear          runtimeMinutes             genres
# 0         \N                      \N  Documentary,Short
# 1         \N                      \N       Comedy,Drama
# 2         \N                      29   Comedy,Game-Show
# 3         \N                      \N               News
# 4         \N                      \N        Documentary
# ...      ...                     ...                ...
# 9020      \N              Reality-TV                NaN
# 9021      \N              Reality-TV                NaN
# 9022      \N                      \N                NaN
# 9023      \N  Animation,Comedy,Drama                NaN
# 9024      \N                      \N                NaN
#
# [9011 rows x 9 columns]

# %% [markdown]
# #### Data dari film yang tidak memiliki judul film sudah dihapus terlihat terdapat pengurangan data dari 9025 data menjadi 9011 data.

# %% [markdown]
# #### Dalam hal ini dilakukan pengecekan terhadap data yang memiliki nilai NULL. Pengecekan dilakukan pada kolom 'genres' yang memiliki data bernilai NULL yang harus dihapus.

# %%
df_film.loc[df_film['genres'].isnull()]
# Out:
#           tconst  titleType  \
# 9014  tt10233364  tvEpisode
# 9015  tt10925142  tvEpisode
# 9016  tt10970874  tvEpisode
# 9017  tt11670006  tvEpisode
# 9018  tt11868642  tvEpisode
# 9019   tt2347742  tvEpisode
# 9020   tt3984412  tvEpisode
# 9021   tt8740950  tvEpisode
# 9022   tt9822816  tvEpisode
# 9023   tt9900062  tvEpisode
# 9024   tt9909210  tvEpisode
#
#                                            primaryTitle originalTitle  \
# 9014  Rolling in the Deep Dish\tRolling in the Deep ...             0
# 9015  The IMDb Show on Location: Star Wars Galaxy's ...             0
# 9016  Die Bauhaus-Stadt Tel Aviv - Vorbild für die M...             0
# 9017  ...ein angenehmer Unbequemer...\t...ein angene...             0
# 9018  GGN Heavyweight Championship Lungs With Mike T...             0
# 9019  No sufras por la alergia esta primavera\tNo su...             0
# 9020  I'm Not Going to Come Last, I'm Just Going to ...             0
# 9021  Weight Loss Resolution Restart - Ins & Outs of...             0
# 9022  Zwischen Vertuschung und Aufklärung - Missbrau...             0
# 9023  The Direction of Yuu's Love: Hings Aren't Goin...             0
# 9024  Politik und/oder Moral - Wie weit geht das Ver...             0
#
#       isAdult startYear endYear          runtimeMinutes genres
# 9014     2019        \N      \N              Reality-TV    NaN
# 9015     2019        \N      \N               Talk-Show    NaN
# 9016     2019        \N      \N                      \N    NaN
# 9017     1981        \N      \N             Documentary    NaN
# 9018     2020        \N      \N               Talk-Show    NaN
# 9019     2004        \N      \N                      \N    NaN
# 9020     2014        \N      \N              Reality-TV    NaN
# 9021     2015        \N      \N              Reality-TV    NaN
# 9022     2019        \N      \N                      \N    NaN
# 9023     1994        \N      \N  Animation,Comedy,Drama    NaN
# 9024     2005        \N      \N                      \N    NaN

# %% [markdown]
# #### Dalam tabel diatas diketahui bahwa semua data tidak terdapat genre film sehingga data-data tersebut harus dihapus.

# %%
df_film=df_film.loc[df_film['genres'].notnull()]

# %%
df_film
# Out:
#           tconst  titleType                                      primaryTitle  \
# 0      tt0221078      short                         Circle Dance, Ute Indians
# 1      tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2      tt7157720  tvEpisode                                     Episode #3.41
# 3      tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4      tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
# ...          ...        ...                                               ...
# 8995   tt1357878  tvEpisode                                            Poison
# 8996   tt2252371  tvEpisode                    Episode dated 20 February 2012
# 8997   tt6934076  tvEpisode                                     Episode #1.59
# 8998  tt11988828  tvEpisode                                    Episode #1.263
# 8999  tt11285464      short                                        Hoodie XXX
#
#                                          originalTitle  isAdult startYear  \
# 0                            Circle Dance, Ute Indians        0      1898
# 1     ¡El #TeamOsos va con todo al "Reality del amor"!        0      2018
# 2                                        Episode #3.41        0      2016
# 3                            Episode dated 16 May 1987        0      1987
# 4                     Frances Bavier: Aunt Bee Retires        0      1973
# ...                                                ...      ...       ...
# 8995                                            Poison        0      2004
# 8996                    Episode dated 20 February 2012        0      2012
# 8997                                     Episode #1.59        0      2012
# 8998                                    Episode #1.263        0        \N
# 8999                                        Hoodie XXX        0      2019
#
#      endYear runtimeMinutes             genres
# 0         \N             \N  Documentary,Short
# 1         \N             \N       Comedy,Drama
# 2         \N             29   Comedy,Game-Show
# 3         \N             \N               News
# 4         \N             \N        Documentary
# ...      ...            ...                ...
# 8995      \N             \N        Documentary
# 8996      \N             \N          Talk-Show
# 8997      \N             \N          Talk-Show
# 8998      \N             \N              Drama
# 8999      \N             \N       Horror,Short
#
# [9000 rows x 9 columns]

# %% [markdown]
# #### Data dari film yang tidak memiliki jenis genre film sudah dihapus terlihat terdapat pengurangan data dari 9011 data menjadi 9000 data

# %% [markdown]
# #### Mengubah data yang mempunyai nilai '\N' .
# #### Pada kolom 'startYear', 'endYear', and 'runtimeMinutes' terdapat data dengan nilai '\N'.
# #### Dimana nilai '\N' ini sama dengan NULL.
# #### Sehingga nilai dari '\N' ini harus diubah menjadi np.nan dan melakukan casting pada kolom 'startYear', 'endYear', dan 'runtimeMinutes' menjadi float64.

# %%
df_film['startYear']=df_film['startYear'].replace('\\N', np.nan)
df_film['startYear']=df_film['startYear'].astype('float64')

df_film['endYear']=df_film['endYear'].replace('\\N', np.nan)
df_film['endYear']=df_film['endYear'].astype('float64')

df_film['runtimeMinutes']=df_film['runtimeMinutes'].replace('\\N', np.nan)
df_film['runtimeMinutes']=df_film['runtimeMinutes'].astype('float64')
# Out:
# <ipython-input-14-e6844086dbb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['startYear']=df_film['startYear'].replace('\\N', np.nan)
# <ipython-input-14-e6844086dbb2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['startYear']=df_film['startYear'].astype('float64')
# <ipython-input-14-e6844086dbb2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['endYear']=df_film['endYear'].replace('\\N', np.nan)
# <ipython-input-14-e6844086dbb2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['endYear']=df_film['endYear'].astype('float64')
# <ipython-input-14-e6844086dbb2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['runtimeMinutes']=df_film['runtimeMinutes'].replace('\\N', np.nan)
# <ipython-input-14-e6844086dbb2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['runtimeMinutes']=df_film['runtimeMinutes'].astype('float64')

# %%
df_film
# Out:
#           tconst  titleType                                      primaryTitle  \
# 0      tt0221078      short                         Circle Dance, Ute Indians
# 1      tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2      tt7157720  tvEpisode                                     Episode #3.41
# 3      tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4      tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
# ...          ...        ...                                               ...
# 8995   tt1357878  tvEpisode                                            Poison
# 8996   tt2252371  tvEpisode                    Episode dated 20 February 2012
# 8997   tt6934076  tvEpisode                                     Episode #1.59
# 8998  tt11988828  tvEpisode                                    Episode #1.263
# 8999  tt11285464      short                                        Hoodie XXX
#
#                                          originalTitle  isAdult  startYear  \
# 0                            Circle Dance, Ute Indians        0     1898.0
# 1     ¡El #TeamOsos va con todo al "Reality del amor"!        0     2018.0
# 2                                        Episode #3.41        0     2016.0
# 3                            Episode dated 16 May 1987        0     1987.0
# 4                     Frances Bavier: Aunt Bee Retires        0     1973.0
# ...                                                ...      ...        ...
# 8995                                            Poison        0     2004.0
# 8996                    Episode dated 20 February 2012        0     2012.0
# 8997                                     Episode #1.59        0     2012.0
# 8998                                    Episode #1.263        0        NaN
# 8999                                        Hoodie XXX        0     2019.0
#
#       endYear  runtimeMinutes             genres
# 0         NaN             NaN  Documentary,Short
# 1         NaN             NaN       Comedy,Drama
# 2         NaN            29.0   Comedy,Game-Show
# 3         NaN             NaN               News
# 4         NaN             NaN        Documentary
# ...       ...             ...                ...
# 8995      NaN             NaN        Documentary
# 8996      NaN             NaN          Talk-Show
# 8997      NaN             NaN          Talk-Show
# 8998      NaN             NaN              Drama
# 8999      NaN             NaN       Horror,Short
#
# [9000 rows x 9 columns]

# %%
df_film.head()
# Out:
#       tconst  titleType                                      primaryTitle  \
# 0  tt0221078      short                         Circle Dance, Ute Indians
# 1  tt8862466  tvEpisode  ¡El #TeamOsos va con todo al "Reality del amor"!
# 2  tt7157720  tvEpisode                                     Episode #3.41
# 3  tt2974998  tvEpisode                         Episode dated 16 May 1987
# 4  tt2903620  tvEpisode                  Frances Bavier: Aunt Bee Retires
#
#                                       originalTitle  isAdult  startYear  \
# 0                         Circle Dance, Ute Indians        0     1898.0
# 1  ¡El #TeamOsos va con todo al "Reality del amor"!        0     2018.0
# 2                                     Episode #3.41        0     2016.0
# 3                         Episode dated 16 May 1987        0     1987.0
# 4                  Frances Bavier: Aunt Bee Retires        0     1973.0
#
#    endYear  runtimeMinutes             genres
# 0      NaN             NaN  Documentary,Short
# 1      NaN             NaN       Comedy,Drama
# 2      NaN            29.0   Comedy,Game-Show
# 3      NaN             NaN               News
# 4      NaN             NaN        Documentary

# %%
print(df_film['startYear'])
# Out:
# 0       1898.0
# 1       2018.0
# 2       2016.0
# 3       1987.0
# 4       1973.0
#          ...
# 8995    2004.0
# 8996    2012.0
# 8997    2012.0
# 8998       NaN
# 8999    2019.0
# Name: startYear, Length: 9000, dtype: float64

# %%
print(df_film['startYear'].unique()[:10])
# Out:
# [1898. 2018. 2016. 1987. 1973. 1951. 2006. 2015. 1998. 2014.]

# %%
print(df_film['endYear'])
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 8995   NaN
# 8996   NaN
# 8997   NaN
# 8998   NaN
# 8999   NaN
# Name: endYear, Length: 9000, dtype: float64

# %%
print(df_film['endYear'].unique()[:10])
# Out:
# [  nan 2005. 1955. 2006. 1999. 2018. 1978. 1997. 2017. 2001.]

# %%
print(df_film['runtimeMinutes'])
# Out:
# 0        NaN
# 1        NaN
# 2       29.0
# 3        NaN
# 4        NaN
#         ...
# 8995     NaN
# 8996     NaN
# 8997     NaN
# 8998     NaN
# 8999     NaN
# Name: runtimeMinutes, Length: 9000, dtype: float64

# %%
print(df_film['runtimeMinutes'].unique()[:10])
# Out:
# [nan 29.  7. 23. 85. 45. 52. 11. 22. 90.]

# %% [markdown]
# #### Mengubah tipe dari kolom 'genres'menjadi list dengan membuat fungsi bernama transform_to_list.

# %%
def transform_to_list(a):
    if ',' in a:
        #apabila ada , dalam kolom genres diubah menjadi list.
        return a.split(',')
    else:
        #jika tidak ada , dalam kolom genres diubah menjadi list yang kosong.
        return []
    
df_film['genres']=df_film['genres'].apply(lambda a: transform_to_list(a))
# Out:
# <ipython-input-23-e5ba2d255c7f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_film['genres']=df_film['genres'].apply(lambda a: transform_to_list(a))

# %% [markdown]
# ### Cleaning NULL data in Ratings File

# %%
df_rating
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.6      1608
# 1        tt0000002            6.0       197
# 2        tt0000003            6.5      1285
# 3        tt0000004            6.1       121
# 4        tt0000005            6.1      2050
# ...            ...            ...       ...
# 1030004  tt9916576            6.0         9
# 1030005  tt9916578            8.4        17
# 1030006  tt9916720            5.6        49
# 1030007  tt9916766            6.8        13
# 1030008  tt9916778            7.2        21
#
# [1030009 rows x 3 columns]

# %%
df_rating.shape
# Out:
# (1030009, 3)

# %%
df_rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.6      1608
# 1  tt0000002            6.0       197
# 2  tt0000003            6.5      1285
# 3  tt0000004            6.1       121
# 4  tt0000005            6.1      2050

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030009 entries, 0 to 1030008
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1030009 non-null  object
#  1   averageRating  1030009 non-null  float64
#  2   numVotes       1030009 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.6+ MB

# %% [markdown]
# ### Joining Basics File and Ratings File
# #### Digunakan inner join untuk menggabungkan Basics File dengan Ratings File. (inner join untuk 2 buah fungsi dari df_film dan df_rating untuk mendapatkan rating pada setiap film yang terdapat di file tersebut, sehingga diperoleh 5 film teratas dan tipe data dari tiap kolom yang ada).

# %%
df_film_rating=pd.merge(df_film, df_rating, on='tconst', how='inner')

# %%
df_film_rating
# Out:
#          tconst  titleType                            primaryTitle  \
# 0     tt0043745      short                               Lion Down
# 1     tt0167491      video                       Wicked Covergirls
# 2     tt6574096  tvEpisode                    Shadow Play - Part 2
# 3     tt6941700  tvEpisode                            RuPaul Roast
# 4     tt7305674      video                UCLA Track & Field Promo
# ...         ...        ...                                     ...
# 1371  tt4027946      movie                   Alone in the Universe
# 1372  tt1119633  tvSpecial                        UFC 67 Countdown
# 1373  tt0290419      movie                       Andru Kanda Mugam
# 1374  tt0522596  tvEpisode                The Clampetts Play Cupid
# 1375  tt7393650  tvEpisode  High Hitler and His Nazi Supersoldiers
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                                  Lion Down        0     1951.0      NaN
# 1                          Wicked Covergirls        1     1998.0      NaN
# 2                       Shadow Play - Part 2        0     2017.0      NaN
# 3                               RuPaul Roast        0     2017.0      NaN
# 4                   UCLA Track & Field Promo        0     2017.0      NaN
# ...                                      ...      ...        ...      ...
# 1371                   Alone in the Universe        0     2015.0      NaN
# 1372                        UFC 67 Countdown        0     2007.0      NaN
# 1373                       Andru Kanda Mugam        0     1968.0      NaN
# 1374                The Clampetts Play Cupid        0     1967.0      NaN
# 1375  High Hitler and His Nazi Supersoldiers        0     2016.0      NaN
#
#       runtimeMinutes                          genres  averageRating  numVotes
# 0                7.0     [Animation, Comedy, Family]            7.1       459
# 1               85.0                              []            5.7         7
# 2               22.0  [Adventure, Animation, Comedy]            8.5       240
# 3                NaN                              []            8.0        11
# 4                NaN                  [Short, Sport]            9.7         7
# ...              ...                             ...            ...       ...
# 1371            97.0        [Comedy, Drama, Romance]            4.1        22
# 1372            60.0                              []            8.0        13
# 1373           164.0                              []            6.4         5
# 1374            30.0                [Comedy, Family]            7.5        38
# 1375             NaN          [Documentary, History]            6.5         8
#
# [1376 rows x 11 columns]

# %%
df_film_rating.shape
# Out:
# (1376, 11)

# %%
df_film_rating.head()
# Out:
#       tconst  titleType              primaryTitle             originalTitle  \
# 0  tt0043745      short                 Lion Down                 Lion Down
# 1  tt0167491      video         Wicked Covergirls         Wicked Covergirls
# 2  tt6574096  tvEpisode      Shadow Play - Part 2      Shadow Play - Part 2
# 3  tt6941700  tvEpisode              RuPaul Roast              RuPaul Roast
# 4  tt7305674      video  UCLA Track & Field Promo  UCLA Track & Field Promo
#
#    isAdult  startYear  endYear  runtimeMinutes  \
# 0        0     1951.0      NaN             7.0
# 1        1     1998.0      NaN            85.0
# 2        0     2017.0      NaN            22.0
# 3        0     2017.0      NaN             NaN
# 4        0     2017.0      NaN             NaN
#
#                            genres  averageRating  numVotes
# 0     [Animation, Comedy, Family]            7.1       459
# 1                              []            5.7         7
# 2  [Adventure, Animation, Comedy]            8.5       240
# 3                              []            8.0        11
# 4                  [Short, Sport]            9.7         7

# %% [markdown]
# #### Menampilkan tipe data untuk tiap kolom.

# %%
df_film_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1376 entries, 0 to 1375
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1376 non-null   object
#  1   titleType       1376 non-null   object
#  2   primaryTitle    1376 non-null   object
#  3   originalTitle   1376 non-null   object
#  4   isAdult         1376 non-null   int64
#  5   startYear       1376 non-null   float64
#  6   endYear         26 non-null     float64
#  7   runtimeMinutes  1004 non-null   float64
#  8   genres          1376 non-null   object
#  9   averageRating   1376 non-null   float64
#  10  numVotes        1376 non-null   int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 129.0+ KB

# %% [markdown]
# ### Memperkecil Ukuran Tabel
# #### Cara untuk memperkecil ukuran tabel yaitu dengan cara menghilangkan semua nilai NULL dari kolom startYear dan runtimeMinutes, karena setiap film pasti diketahui tahun rilis film dan durasi film.

# %%
df_film_rating=df_film_rating.dropna(subset=['startYear','runtimeMinutes'])

# %%
df_film_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1004 entries, 0 to 1374
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1004 non-null   object
#  1   titleType       1004 non-null   object
#  2   primaryTitle    1004 non-null   object
#  3   originalTitle   1004 non-null   object
#  4   isAdult         1004 non-null   int64
#  5   startYear       1004 non-null   float64
#  6   endYear         17 non-null     float64
#  7   runtimeMinutes  1004 non-null   float64
#  8   genres          1004 non-null   object
#  9   averageRating   1004 non-null   float64
#  10  numVotes        1004 non-null   int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 94.1+ KB

# %% [markdown]
# ### Membangun Simple Recommender System
# #### Dengan menggunakan formula rumus dari IMDB Weighted Average, disini sudah diketahui nilai dari v dan R, sehingga perlu dicari terlebih dahulu nilai dari C dan m.

# %%
C=df_film_rating['averageRating'].mean()

# %%
print(C)
# Out:
# 6.829581673306767

# %%
m=df_film_rating['numVotes'].quantile(0.8)

# %%
print(m)
# Out:
# 229.0

# %% [markdown]
# #### Membut Fungsi dari IMDB Weighted Average

# %%
def imdb_weighted_filmrating(df_imdb, var = 0.8):
    v=df_imdb['numVotes']
    R=df_imdb['averageRating']
    C=df_imdb['averageRating'].mean()
    m=df_imdb['numVotes'].quantile(var)
    df_imdb['value']=(v/(m+v))*R + (m/(m+v))*C
    return df_imdb['value']

# %%
imdb_weighted_filmrating(df_film_rating)
# Out:
# <ipython-input-39-3c0a64195ff1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imdb['value']=(v/(m+v))*R + (m/(m+v))*C
# 0       7.009992
# 1       6.796077
# 2       7.684380
# 5       6.921384
# 6       6.869089
#           ...
# 1369    6.867943
# 1371    6.590335
# 1372    6.892455
# 1373    6.820403
# 1374    6.924997
# Name: value, Length: 1004, dtype: float64

# %%
df_film_rating
# Out:
#          tconst  titleType              primaryTitle  \
# 0     tt0043745      short                 Lion Down
# 1     tt0167491      video         Wicked Covergirls
# 2     tt6574096  tvEpisode      Shadow Play - Part 2
# 5     tt2262289      movie                   The Pin
# 6     tt0874027  tvEpisode             Episode #32.9
# ...         ...        ...                       ...
# 1369  tt8870226      video         Sublime: Santeria
# 1371  tt4027946      movie     Alone in the Universe
# 1372  tt1119633  tvSpecial          UFC 67 Countdown
# 1373  tt0290419      movie         Andru Kanda Mugam
# 1374  tt0522596  tvEpisode  The Clampetts Play Cupid
#
#                  originalTitle  isAdult  startYear  endYear  runtimeMinutes  \
# 0                    Lion Down        0     1951.0      NaN             7.0
# 1            Wicked Covergirls        1     1998.0      NaN            85.0
# 2         Shadow Play - Part 2        0     2017.0      NaN            22.0
# 5                      The Pin        0     2013.0      NaN            85.0
# 6                Episode #32.9        0     2006.0      NaN            29.0
# ...                        ...      ...        ...      ...             ...
# 1369         Sublime: Santeria        0     1996.0      NaN             4.0
# 1371     Alone in the Universe        0     2015.0      NaN            97.0
# 1372          UFC 67 Countdown        0     2007.0      NaN            60.0
# 1373         Andru Kanda Mugam        0     1968.0      NaN           164.0
# 1374  The Clampetts Play Cupid        0     1967.0      NaN            30.0
#
#                               genres  averageRating  numVotes     value
# 0        [Animation, Comedy, Family]            7.1       459  7.009992
# 1                                 []            5.7         7  6.796077
# 2     [Adventure, Animation, Comedy]            8.5       240  7.684380
# 5                                 []            7.7        27  6.921384
# 6          [Comedy, Game-Show, News]            8.0         8  6.869089
# ...                              ...            ...       ...       ...
# 1369                  [Music, Short]            7.6        12  6.867943
# 1371        [Comedy, Drama, Romance]            4.1        22  6.590335
# 1372                              []            8.0        13  6.892455
# 1373                              []            6.4         5  6.820403
# 1374                [Comedy, Family]            7.5        38  6.924997
#
# [1004 rows x 12 columns]

# %%
df_film_rating.shape
# Out:
# (1004, 12)

# %%
df_film_rating.head()
# Out:
#       tconst  titleType          primaryTitle         originalTitle  isAdult  \
# 0  tt0043745      short             Lion Down             Lion Down        0
# 1  tt0167491      video     Wicked Covergirls     Wicked Covergirls        1
# 2  tt6574096  tvEpisode  Shadow Play - Part 2  Shadow Play - Part 2        0
# 5  tt2262289      movie               The Pin               The Pin        0
# 6  tt0874027  tvEpisode         Episode #32.9         Episode #32.9        0
#
#    startYear  endYear  runtimeMinutes                          genres  \
# 0     1951.0      NaN             7.0     [Animation, Comedy, Family]
# 1     1998.0      NaN            85.0                              []
# 2     2017.0      NaN            22.0  [Adventure, Animation, Comedy]
# 5     2013.0      NaN            85.0                              []
# 6     2006.0      NaN            29.0       [Comedy, Game-Show, News]
#
#    averageRating  numVotes     value
# 0            7.1       459  7.009992
# 1            5.7         7  6.796077
# 2            8.5       240  7.684380
# 5            7.7        27  6.921384
# 6            8.0         8  6.869089

# %% [markdown]
# ### Cara Pembuatan Simple Recommender System
# #### Dari perhitungan IMDB Weigted Average diperoleh kolom tambahan berupa value. Langkah pertama adalah memfilter numVotes yang lebih dari m kemudia mengurutkan value dari tertinggi ke terendah untuk diambil beberapa value teratas.

# %%
def simple_recommender(df_recommender, top = 100):
    df_recommender=df_recommender.loc[df_recommender['numVotes'] >= m]
    df_recommender=df_recommender.sort_values(by='value', ascending=False) #untuk mengurutkan dari value tertinggi ke value terndah
    
    #mengambil 100 data dengan value teratas
    df_recommender=df_recommender[:100]
    return df_recommender

# %% [markdown]
# #### Mengambil 25 data dengan value teratas.

# %%
simple_recommender(df_film_rating, top=25)
# Out:
#          tconst  titleType                         primaryTitle  \
# 68    tt4110822  tvEpisode                        S.O.S. Part 2
# 236   tt2200252      video          Attack of the Clones Review
# 1181  tt7697962  tvEpisode  Chapter Seventeen: The Missionaries
# 326   tt7124590  tvEpisode  Chapter Thirty-Four: Judgment Night
# 1045  tt0533506  tvEpisode                             The Prom
# ...         ...        ...                                  ...
# 1105  tt0098325      movie                     Sidewalk Stories
# 728   tt0519603  tvEpisode                     Moon of the Wolf
# 453   tt0091658      movie                           Nutcracker
# 758   tt0095305      movie                            High Tide
# 1316  tt1223932      movie                        Time of Peace
#
#                             originalTitle  isAdult  startYear  endYear  \
# 68                          S.O.S. Part 2        0     2015.0      NaN
# 236           Attack of the Clones Review        0     2010.0      NaN
# 1181  Chapter Seventeen: The Missionaries        0     2019.0      NaN
# 326   Chapter Thirty-Four: Judgment Night        0     2018.0      NaN
# 1045                             The Prom        0     1999.0      NaN
# ...                                   ...      ...        ...      ...
# 1105                     Sidewalk Stories        0     1989.0      NaN
# 728                      Moon of the Wolf        0     1992.0      NaN
# 453                            Nutcracker        0     1986.0      NaN
# 758                             High Tide        0     1987.0      NaN
# 1316                        Tempos de Paz        0     2009.0      NaN
#
#       runtimeMinutes                          genres  averageRating  numVotes  \
# 68              43.0      [Action, Adventure, Drama]            9.4      3820
# 236             86.0                              []            9.3      1411
# 1181            54.0        [Drama, Fantasy, Horror]            9.2      1536
# 326             42.0         [Crime, Drama, Mystery]            9.1      1859
# 1045            60.0        [Action, Drama, Fantasy]            8.9      2740
# ...              ...                             ...            ...       ...
# 1105            97.0                              []            7.1       287
# 728             22.0  [Action, Adventure, Animation]            7.0       926
# 453             89.0        [Family, Fantasy, Music]            7.0       838
# 758            101.0                              []            7.0       765
# 1316            80.0                              []            7.0       517
#
#          value
# 68    9.254624
# 236   8.955045
# 1181  8.892450
# 326   8.850993
# 1045  8.740308
# ...        ...
# 1105  6.979989
# 728   6.966211
# 453   6.963425
# 758   6.960739
# 1316  6.947687
#
# [100 rows x 12 columns]

# %% [markdown]
# #### Berikutnya adalah cara membuat simple recommender system dengan menggunakan user preferences.
# #### Dari simple recommender system sebelumnya sudah didapatkan daftar film yang telah diurutkan dari value tertinggi sampai value terendah.
# #### Film dengan averageRating tinggi tidak selalu mendapatkan posisi urutan tinggi dii value dibandingkan dengan averageRating yang rendah, hal ini disebabkan oleh pertimbangan dari perhitungan faktor banyaknya votes.
# #### Sistem rekomendasi untuk film ini masih dapat ditingkatkan lagi dengan menambahka filter yang lebih spesifik untuk 'titleType', 'startYear', 'genres', ataupun yang lainnya.
# #### Selanjutnya, membuat function untuk melakukan pemfilteran berdasarkan isAdult, startYear, dan genres.

# %%
df_next_recommender=df_film_rating.copy()

def user_preference_recommender(df_next_recommender, ask_adult, ask_start_year, ask_genre, top=100):
    #bagian untuk ask_adult dengan output yes atau no.
    if ask_adult.lower() == 'yes':
        df_next_recommender=df_next_recommender.loc[df_next_recommender['isAdult'] == 1]
    elif ask_adult.lower() == 'no':
        df_next_recommender=df_next_recommender.loc[df_next_recommender['isAdult'] == 0]
        
    #bagian untuk ask_start_year dengan output berupa data numeric
    df_next_recommender=df_next_recommender.loc[df_next_recommender['startYear'] >= int(ask_start_year)]
    
    #bagian untuk ask_genre dengan output berupa all genre atau yang lain
    if ask_genre.lower() == 'all':
        df_next_recommender=df_next_recommender
    else:
        def filter_genre(g):
            if ask_genre.lower() in str(g).lower():
                return True
            else:
                return False
        df_next_recommender=df_next_recommender.loc[df_next_recommender['genres'].apply(lambda g: filter_genre(g))]
        
    #bagian untuk output dari numVotes berdasarkan value dari perhitungan dengan IMDB Weighted Average.
    df_next_recommender=df_next_recommender.loc[df_next_recommender['numVotes'] >= m] #mengambil data dengan m yang lebih besar daripada numVotes.
    df_next_recommender=df_next_recommender.sort_values(by='value', ascending=False)
    
    #Pengambilan untuk 100 film teratas
    df_next_recommender=df_next_recommender[:top]
    return df_next_recommender

# %%
user_preference_recommender(df_next_recommender,
                           ask_adult = 'no',
                           ask_start_year = 2005,
                           ask_genre ='drama')
# Out:
#          tconst  titleType                         primaryTitle  \
# 68    tt4110822  tvEpisode                        S.O.S. Part 2
# 1181  tt7697962  tvEpisode  Chapter Seventeen: The Missionaries
# 326   tt7124590  tvEpisode  Chapter Thirty-Four: Judgment Night
# 71    tt8399426  tvEpisode                              Savages
# 1234  tt2843830  tvEpisode                                VIII.
# 1054  tt2503932  tvEpisode                      Trial and Error
# 1281  tt3166390  tvEpisode               Looking for a Plus-One
# 151   tt3954426  tvEpisode                      Bleeding Kansas
# 1344  tt6644294  tvEpisode       The Hostile Hospital: Part Two
# 357   tt4084774  tvEpisode                 Trial and Punishment
# 708   tt2751234  tvEpisode                         Resurrection
# 605   tt9141176  tvEpisode                59 horas desaparecido
# 983   tt5063116  tvEpisode                                Shell
# 1017  tt2206822  tvEpisode                      Vested Interest
# 73    tt0847785  tvEpisode                          Like It Was
# 625   tt7348490  tvEpisode                   Forced Perspective
# 800   tt0901201  tvEpisode                           Crossroads
# 659   tt3909890  tvEpisode                                Moppa
# 1001  tt2129485  tvEpisode                      A Desperate Man
# 977   tt4391820  tvEpisode                              Aisling
# 1096  tt6822518      movie                    Yasamak Güzel Sey
# 910   tt3348270  tvEpisode                            Bloodline
# 299   tt4527626  tvEpisode                His Troubled Thoughts
# 509   tt1256301  tvEpisode                           Nine Lives
# 897   tt2349242  tvEpisode                        The Fifth Man
# 109   tt1753383      movie                      A Dog's Purpose
# 550   tt8163822      short                The Neighbors' Window
# 834   tt6509862      movie                             Mr. Long
# 642   tt0993186  tvEpisode                  Daleks in Manhattan
# 691   tt3663996  tvEpisode                          Storm Watch
# 727   tt3563898   tvSeries            Brynhildr in the Darkness
# 164   tt0464049      movie                     The History Boys
# 893   tt8858104      movie                         Guava Island
# 927   tt3663990  tvEpisode                                Pilot
# 462   tt5197828  tvEpisode                                Right
# 1068  tt8369852  tvEpisode              I Think We're Alone Now
# 610   tt3526706      movie                            Chevalier
# 1126  tt2151739      movie                Meet Me in Montenegro
# 637   tt0857275      movie                      Wonderful World
# 385   tt0472259      movie                       Alone with Her
# 1014  tt1159705      movie                        Teenage Angst
# 1043  tt5518756      movie                      The Misandrists
# 1154  tt1386492      movie                  This Is Not a Movie
# 492   tt0882806      movie                           Sugar Boxx
# 922   tt2948790      movie                     Return to Sender
# 690   tt4477536      movie                   Fifty Shades Freed
# 677   tt8923408  tvEpisode                          #JinnHunter
# 1039  tt5227468      movie                        Beiimaan Love
# 1138  tt1126516      movie              Money Hai Toh Honey Hai
# 1208  tt3044882      movie                                Nasha
# 1197  tt3016748      movie                       Jacob's Ladder
# 846   tt0488164      movie                          Moscow Zero
# 90    tt0299981    tvMovie               Highlander: The Source
#
#                             originalTitle  isAdult  startYear  endYear  \
# 68                          S.O.S. Part 2        0     2015.0      NaN
# 1181  Chapter Seventeen: The Missionaries        0     2019.0      NaN
# 326   Chapter Thirty-Four: Judgment Night        0     2018.0      NaN
# 71                                Savages        0     2018.0      NaN
# 1234                                VIII.        0     2014.0      NaN
# 1054                      Trial and Error        0     2013.0      NaN
# 1281               Looking for a Plus-One        0     2014.0      NaN
# 151                       Bleeding Kansas        0     2014.0      NaN
# 1344       The Hostile Hospital: Part Two        0     2018.0      NaN
# 357                  Trial and Punishment        0     2015.0      NaN
# 708                          Resurrection        0     2014.0      NaN
# 605                 59 horas desaparecido        0     2019.0      NaN
# 983                                 Shell        0     2016.0      NaN
# 1017                      Vested Interest        0     2012.0      NaN
# 73                            Like It Was        0     2006.0      NaN
# 625                    Forced Perspective        0     2018.0      NaN
# 800                            Crossroads        0     2006.0      NaN
# 659                                 Moppa        0     2014.0      NaN
# 1001                      A Desperate Man        0     2012.0      NaN
# 977                               Aisling        0     2019.0      NaN
# 1096                    Yasamak Güzel Sey        0     2017.0      NaN
# 910                             Bloodline        0     2014.0      NaN
# 299                 His Troubled Thoughts        0     2016.0      NaN
# 509                            Nine Lives        0     2008.0      NaN
# 897                         The Fifth Man        0     2012.0      NaN
# 109                       A Dog's Purpose        0     2017.0      NaN
# 550                 The Neighbors' Window        0     2019.0      NaN
# 834                               Ryu san        0     2017.0      NaN
# 642                   Daleks in Manhattan        0     2007.0      NaN
# 691                           Storm Watch        0     2014.0      NaN
# 727                 Gokukoku no Brynhildr        0     2014.0      NaN
# 164                      The History Boys        0     2006.0      NaN
# 893                          Guava Island        0     2019.0      NaN
# 927                                 Pilot        0     2014.0      NaN
# 462                                 Right        0     2016.0      NaN
# 1068              I Think We're Alone Now        0     2019.0      NaN
# 610                             Chevalier        0     2015.0      NaN
# 1126                Meet Me in Montenegro        0     2014.0      NaN
# 637                       Wonderful World        0     2009.0      NaN
# 385                        Alone with Her        0     2006.0      NaN
# 1014                        Teenage Angst        0     2008.0      NaN
# 1043                      The Misandrists        0     2017.0      NaN
# 1154                  This Is Not a Movie        0     2011.0      NaN
# 492                            Sugar Boxx        0     2009.0      NaN
# 922                      Return to Sender        0     2015.0      NaN
# 690                    Fifty Shades Freed        0     2018.0      NaN
# 677                           #JinnHunter        0     2019.0      NaN
# 1039                        Beiimaan Love        0     2016.0      NaN
# 1138              Money Hai Toh Honey Hai        0     2008.0      NaN
# 1208                                Nasha        0     2013.0      NaN
# 1197                       Jacob's Ladder        0     2019.0      NaN
# 846                           Moscow Zero        0     2006.0      NaN
# 90                 Highlander: The Source        0     2007.0      NaN
#
#       runtimeMinutes                       genres  averageRating  numVotes  \
# 68              43.0   [Action, Adventure, Drama]            9.4      3820
# 1181            54.0     [Drama, Fantasy, Horror]            9.2      1536
# 326             42.0      [Crime, Drama, Mystery]            9.1      1859
# 71              58.0    [Drama, Fantasy, Romance]            9.0      1428
# 1234            57.0           [Adventure, Drama]            8.9      1753
# 1054            43.0     [Drama, Fantasy, Horror]            8.6      2495
# 1281            28.0     [Comedy, Drama, Romance]            8.7       396
# 151             42.0             [Drama, Western]            8.6       437
# 1344            40.0   [Adventure, Comedy, Drama]            8.3       812
# 357             56.0           [Adventure, Drama]            8.8       289
# 708             43.0       [Crime, Drama, Horror]            8.0      1077
# 605             48.0     [Crime, Drama, Thriller]            8.1       674
# 983             32.0              [Comedy, Drama]            8.5       275
# 1017            43.0       [Comedy, Crime, Drama]            8.0       525
# 73              43.0     [Comedy, Drama, Mystery]            8.1       405
# 625             43.0      [Crime, Drama, Mystery]            7.9       413
# 800             42.0     [Action, Drama, Mystery]            7.7       654
# 659             27.0              [Comedy, Drama]            7.8       410
# 1001            44.0       [Action, Crime, Drama]            7.7       501
# 977             51.0      [Crime, Drama, Fantasy]            7.5      1558
# 1096           101.0              [Comedy, Drama]            7.5      1541
# 910             44.0     [Drama, Horror, Mystery]            7.7       436
# 299             59.0     [Crime, Drama, Thriller]            7.5       859
# 509             44.0       [Action, Crime, Drama]            7.6       501
# 897             44.0       [Action, Crime, Drama]            7.8       270
# 109            100.0   [Adventure, Comedy, Drama]            7.2     61521
# 550             21.0               [Drama, Short]            7.2      2222
# 834            129.0       [Action, Crime, Drama]            7.1       960
# 642             45.0   [Adventure, Drama, Family]            7.0      4982
# 691             43.0             [Drama, Romance]            7.0       309
# 727             22.0   [Action, Animation, Drama]            6.8       733
# 164            109.0     [Comedy, Drama, Romance]            6.8     19858
# 893             55.0       [Comedy, Drama, Music]            6.7      7935
# 927             44.0             [Drama, Romance]            6.6       403
# 462             42.0      [Crime, Drama, Mystery]            6.5       641
# 1068            43.0  [Adventure, Drama, Mystery]            6.3       563
# 610            105.0              [Comedy, Drama]            6.3      3890
# 1126            90.0     [Comedy, Drama, Romance]            5.8       258
# 637             89.0             [Drama, Romance]            6.1      2288
# 385             78.0     [Crime, Drama, Thriller]            6.0      3738
# 1014            64.0            [Drama, Thriller]            5.3       355
# 1043            91.0              [Comedy, Drama]            5.1       387
# 1154            99.0              [Comedy, Drama]            4.6       642
# 492             86.0               [Crime, Drama]            3.5       229
# 922             92.0            [Drama, Thriller]            5.1     11434
# 690            105.0   [Drama, Romance, Thriller]            4.5     50572
# 677             24.0     [Drama, Fantasy, Horror]            3.6       592
# 1039           120.0   [Drama, Romance, Thriller]            2.8       374
# 1138           138.0              [Comedy, Drama]            2.8       527
# 1208           122.0            [Drama, Thriller]            3.2      1132
# 1197            89.0     [Drama, Horror, Mystery]            3.4      2065
# 846             82.0      [Action, Drama, Horror]            3.0      1620
# 90              86.0   [Action, Adventure, Drama]            3.1      8855
#
#          value
# 68    9.254624
# 1181  8.892450
# 326   8.850993
# 71    8.700045
# 1234  8.660784
# 1054  8.451165
# 1281  8.014679
# 151   7.991253
# 1344  7.976536
# 357   7.928908
# 708   7.794774
# 605   7.777823
# 983   7.741020
# 1017  7.644528
# 73    7.641127
# 625   7.518184
# 800   7.474263
# 659   7.452229
# 1001  7.426951
# 977   7.414087
# 1096  7.413262
# 910   7.400262
# 299   7.358892
# 509   7.358321
# 897   7.354658
# 109   7.198626
# 550   7.165391
# 834   7.047918
# 642   6.992511
# 691   6.927461
# 727   6.807042
# 164   6.800337
# 893   6.703635
# 927   6.683187
# 462   6.586752
# 1068  6.453124
# 610   6.329443
# 1126  6.284136
# 637   6.166378
# 385   6.047889
# 1014  5.899785
# 1043  5.742978
# 1154  5.186193
# 492   5.164791
# 922   5.133960
# 690   4.510501
# 677   4.500821
# 1039  4.330305
# 1138  4.020601
# 1208  3.810708
# 1197  3.742360
# 846   3.474296
# 90    3.194020

# %%
user_preference_recommender(df_next_recommender,
                           ask_adult = 'yes',
                           ask_start_year = 1990,
                           ask_genre ='action')
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres, averageRating, numVotes, value]
# Index: []

# %%
user_preference_recommender(df_next_recommender,
                           ask_adult = 'yes',
                           ask_start_year = 2005,
                           ask_genre ='horror')
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres, averageRating, numVotes, value]
# Index: []

# %%
user_preference_recommender(df_next_recommender,
                           ask_adult = 'no',
                           ask_start_year = 2005,
                           ask_genre ='horror')
# Out:
#          tconst  titleType                                       primaryTitle  \
# 1181  tt7697962  tvEpisode                Chapter Seventeen: The Missionaries
# 1054  tt2503932  tvEpisode                                    Trial and Error
# 708   tt2751234  tvEpisode                                       Resurrection
# 910   tt3348270  tvEpisode                                          Bloodline
# 298   tt9597142  tvEpisode  Skincrawlers/By the Silver Water of Lake Champ...
# 902   tt3820128      short                                           The Herd
# 1367  tt4031126      movie                                              Lycan
# 583   tt7039000      movie                                American Nightmares
# 484   tt3138376      video                              Joy Ride 3: Road Kill
# 677   tt8923408  tvEpisode                                        #JinnHunter
# 693   tt4464394      movie                            The Gracefield Incident
# 1197  tt3016748      movie                                     Jacob's Ladder
# 846   tt0488164      movie                                        Moscow Zero
#
#                                           originalTitle  isAdult  startYear  \
# 1181                Chapter Seventeen: The Missionaries        0     2019.0
# 1054                                    Trial and Error        0     2013.0
# 708                                        Resurrection        0     2014.0
# 910                                           Bloodline        0     2014.0
# 298   Skincrawlers/By the Silver Water of Lake Champ...        0     2019.0
# 902                                            The Herd        0     2014.0
# 1367                                              Lycan        0     2017.0
# 583                                      Mr. Malevolent        0     2018.0
# 484                               Joy Ride 3: Road Kill        0     2014.0
# 677                                         #JinnHunter        0     2019.0
# 693                             The Gracefield Incident        0     2017.0
# 1197                                     Jacob's Ladder        0     2019.0
# 846                                         Moscow Zero        0     2006.0
#
#       endYear  runtimeMinutes                     genres  averageRating  \
# 1181      NaN            54.0   [Drama, Fantasy, Horror]            9.2
# 1054      NaN            43.0   [Drama, Fantasy, Horror]            8.6
# 708       NaN            43.0     [Crime, Drama, Horror]            8.0
# 910       NaN            44.0   [Drama, Horror, Mystery]            7.7
# 298       NaN            44.0          [Fantasy, Horror]            7.1
# 902       NaN            21.0  [Horror, Short, Thriller]            6.5
# 1367      NaN            87.0         [Horror, Thriller]            5.0
# 583       NaN            90.0           [Comedy, Horror]            4.1
# 484       NaN            95.0  [Crime, Horror, Thriller]            4.7
# 677       NaN            24.0   [Drama, Fantasy, Horror]            3.6
# 693       NaN            89.0  [Action, Horror, Mystery]            4.1
# 1197      NaN            89.0   [Drama, Horror, Mystery]            3.4
# 846       NaN            82.0    [Action, Drama, Horror]            3.0
#
#       numVotes     value
# 1181      1536  8.892450
# 1054      2495  8.451165
# 708       1077  7.794774
# 910        436  7.400262
# 298        294  6.981595
# 902        230  6.664432
# 1367       959  5.352672
# 583        518  4.936779
# 484       4191  4.810334
# 677        592  4.500821
# 693       2026  4.377195
# 1197      2065  3.742360
# 846       1620  3.474296
